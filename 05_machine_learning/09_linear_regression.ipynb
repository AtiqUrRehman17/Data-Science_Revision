# %% [markdown]
# # **Linear Regression**
# Linear Regression is is a supervised machine learning alogrithem where the predicted outocmes is continous and has a canstant slope.its used to pridect values within a continous range, eg(sales,price) rather then trying to classify them into categories (eg,cat,dog).
# There are main two types :
# **Simple linear regression** : only one idependent varablie(sales) \
# **Multi Libear regression** : more then one independent variables(sale,price)

# %% [markdown]
# # Linear Regression Assumtions
# 1. Linearaty of Residules (Random errors y-act - y-pred)
# 2. Independance of Rasidules.
# 3. Normal distribution of the rasidules

# %% [markdown]
# # **Simple Linear Regression**

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = df[['total_bill']]
scalar = MinMaxScaler()
X = scalar.fit_transform(X)
y = df['tip']

# %%
X
# Out:
# array([[0.29157939],
#        [0.1522832 ],
#        [0.3757855 ],
#        [0.43171345],
#        [0.45077503],
#        [0.46543779],
#        [0.11939673],
#        [0.49874319],
#        [0.25073314],
#        [0.24528697],
#        [0.15081693],
#        [0.67427734],
#        [0.25869292],
#        [0.32174277],
#        [0.24633431],
#        [0.38772518],
#        [0.15207373],
#        [0.27691663],
#        [0.29116045],
#        [0.36824466],
#        [0.31105991],
#        [0.36070381],
#        [0.2660243 ],
#        [0.761416  ],
#        [0.35085882],
#        [0.30875576],
#        [0.21575199],
#        [0.20150817],
#        [0.39023879],
#        [0.34729786],
#        [0.13573523],
#        [0.32006703],
#        [0.25115207],
#        [0.36908253],
#        [0.30812736],
#        [0.43967323],
#        [0.27733557],
#        [0.29032258],
#        [0.32718894],
#        [0.59069962],
#        [0.27167993],
#        [0.30142438],
#        [0.22769166],
# ...

# %%
y
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
# call the model
model = LinearRegression()

# %%
# fit the model
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# pridect
y_pred = model.predict(X_test)

# %%
# take out the model intercept and slope and make an equation of it
print(model.intercept_)
print(model.coef_)
print('y = ',model.intercept_,'+',model.coef_,' * X')
# Out:
# 1.153679543273962
# [5.12243828]
# y =  1.153679543273962 + [5.12243828]  * X

# %%
y_test
# Out:
# 54     4.34
# 71     3.00
# 150    2.50
# 152    2.74
# 198    2.00
# 64     2.64
# 15     3.92
# 173    3.18
# 28     4.30
# 211    5.16
# 35     3.60
# 219    3.09
# 110    3.00
# 238    4.67
# 200    4.00
# 135    1.25
# 59     6.73
# 167    4.50
# 90     3.00
# 181    5.65
# 4      3.61
# 7      3.12
# 27     2.00
# 194    4.00
# 197    5.00
# 13     3.00
# 79     2.71
# 62     1.98
# 164    3.00
# 188    3.50
# 216    3.00
# 125    4.20
# 85     5.17
# 1      1.66
# 224    1.58
# 46     5.00
# 187    2.00
# 222    1.92
# 157    3.75
# 172    5.15
# 230    2.00
# 33     2.45
# 63     3.76
# 193    2.02
# 34     3.27
# 43     1.32
# 17     3.71
# 44     5.60
# 205    3.23
# Name: tip, dtype: float64

# %%
y_pred
# Out:
# array([3.56682653, 2.65586086, 2.33396486, 2.6762476 , 2.21915529,
#        2.71165616, 3.13977784, 4.24173513, 3.15265368, 3.60223509,
#        3.40587853, 4.05825441, 2.32645396, 4.66878382, 2.83183067,
#        1.73738428, 6.00357922, 4.22671332, 3.93271498, 3.3275505 ,
#        3.46274682, 3.70846077, 2.1858927 , 2.60328451, 5.4499181 ,
#        2.80178704, 2.67946656, 2.00670393, 2.70307227, 2.77174342,
#        3.84473007, 4.02177287, 4.56148516, 1.93374084, 2.26422073,
#        3.20952197, 4.09258999, 1.74489519, 3.50673927, 1.60218796,
#        3.4005136 , 3.04428203, 2.78676523, 2.48525598, 2.73204291,
#        1.86292372, 2.5721679 , 4.08615207, 2.59148166])

# %%
# evaluate the model
print('MSE = ',mean_squared_error(y_test,y_pred))
print('R Square Score = ',r2_score(y_test,y_pred))
print('RMSE = ',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# MSE =  1.0075354205361917
# R Square Score =  0.34745421531757525
# RMSE =  1.0037606390650071

# %%
# plot the model and data
plt.scatter(X_test,y_test)
plt.plot(X_test,y_pred,color = 'red')
plt.show()
